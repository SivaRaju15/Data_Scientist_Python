# %%
import numpy as np
a = np.arange(2,49,2)
a

# %%
b = np.array([1,34,2,32,3,45,4,56,5,67,6,78,7,89,8,90])
c = np.arange(b[0], b[1], b[2])
print(c)

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd  # Required import

# 1D container called a Series
data = [2, 3, 4, 5, 6, 11, 12, 13, 14, 15]  # Fixed variable name (no numbers at start)
series = pd.Series(data)

print(series)
print(type(series))
print(series[0])  # Accessing the first element of the Series

# %%
a

# %%
print(a.ndim)
print(a.shape)
print(a[3])

# %% [markdown]
# ### Dictionary

# %%
mydict = {'Name': ['Rajoo', 'Raju', 'Raja', 'Raj'], 'Age': [23, 24, 25, 26], 'City': ['Delhi', 'Mumbai', 'Chennai', 'Kolkata'], 'b': [1, 34, 2], 'c': np.arange(1, 34, 2),2: np.arange(1, 34, 2),6: [1, 34, ]}
ser1 = pd.Series(mydict)
ser1

# %%
print(ser1['Name'])

# %%
print(ser1['City'])

# %%
print(ser1[2])

# %% [markdown]
# ### Slice

# %%
print(ser1[1:5])

# %%
print(ser1[0:2])

# %%
print(ser1['Name':'City'])

# %%
d = pd.Series(np.arange(1, 10))
print(d)

# %% [markdown]
# ### DataFrame -----> 2d dim container

# %%
a = [["Raju",24,"Delhi"],["Lavanya",25,"Mumbai"],["Rahul",26,"Chennai"]]
b = pd.DataFrame(a,columns=['Name','Age','City'])
b

# %%
dict1 = {'PID': [1, 2, 3, 4, 5], 'Name': ['Pepsi', 'Coke', 'Sprite', 'Fanta', 'Mountain Dew'], 'quantity': [100, 200, 150, 120, 180], 'Price': [200, 150, 180, 170, 160]}

# %%
df = pd.DataFrame(dict1)
df

# %%
pwd

# %%
import pandas as pd
df = pd.read_csv("train.csv")
df.head()

# %%
df.describe()

# %%
df.tail()

# %%
df

# %%
df.columns

# %%
df['Pclass'].unique()

# %%
df.shape
